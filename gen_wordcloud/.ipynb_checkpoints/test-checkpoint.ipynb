# %%
import requests
from html2text import html2text
import re

import jieba
from wordcloud import WordCloud

url = "https://mp.weixin.qq.com/s?src=11&timestamp=1528088401&ver=917&signature=mu7MyiQ-AK-rWoaQCDq7t81l39YvM4PRti-NwPkQ0q-JLDn4C2ezzP9jezDJeLNM0l3n0pjItw*6oLy7-ypfgyjyvskbMdCXR98pdMA2wlA-3uN7lTS1Le3IBmoB28GJ&new=1"

r = requests.get(url)
text = html2text(r.text)

# pic = re.findall((r'!\[\S+?)'), text)

seg_list = jieba.cut(text, cut_all=False)

# %%
seg = list(seg_list)

# %%
len(seg)
# Out:
# 2296

# %%
for i in seg:
    if len(i) >= 5:
        print(len(i), i)
# Out:
# 10 javascript
# 7 nbdnews
# 6 国家税务总局
# 6 国家税务总局
# 6 国家税务总局
# 7 nbdnews
# 5 https
# 6 weixin
# 12 ODYzMzExMzQx
# 10 2652738135
# 32 ec02c155931a3e615cc8c9d3d65b5297
# 5 chksm
# 76 00a3d0d537d459c366aa52b2cd3d4b18986c35ee5a18e72bed0dc39bf0bce4a32c6d91506ffa
# 5 scene
# 6 wechat
# 8 redirect
# 5 百分之三十
# 5 百分之三十
# 6 国家税务总局
# 6 国家税务总局
# 7 nbdnews
# 6 国家税务总局
# 7 nbdnews
# 7 nbdnews
# 7 nbdnews
# 7 nbdnews
# 6 weixin
# 12 ODYzMzExMzQx
# 10 2652738540
# 32 e09d630e518e8c5fae4c7dcd935dd5e0
# 5 chksm
# 76 00a3d16e37d458788804edae1b99268017eaff60b6a72c622fc550c0a945891510a02652f90d
# 5 scene
# 6 wechat
# 8 redirect
# 6 weixin
# 12 ODYzMzExMzQx
# 10 2652738520
# 32 652d11e45fdb66158dc37b531ae3cb78
# 5 chksm
# 76 00a3d15a37d4584c42c3738a43f93deb624fe02b8655448b1dacae9ca9055653d1b79a49bd23
# 5 scene
# 6 wechat
# 8 redirect
# 6 weixin
# 12 ODYzMzExMzQx
# 10 2652738520
# 32 a245c61e3e5917268b63fdc59cb44599
# 5 chksm
# 76 00a3d15a37d4584c52601cae8b7a6a5b3aaa554536738cea2bc3a4b57200665e392aadadd8c2
# ...

# %%
def segment(text):
    '''
    对一段text进行分词
    input：
    text:待分词的原始文章

    return:
    seg:分词后的text list
    '''
    source_text = text
    stop_words=[]
    # 得到分词原始list
    seg_list = list(jieba.cut((source_text), cut_all=False))

    # 加载停用词，转化为一个list一个词为一个项目
    with open('stop_words.txt') as f:
        stop_words = f.read().splitlines()
        
    # 将单个文档分词成为一个list，文档集合和文档list的集合
    seg=[]
    for i in seg_list:
        if i=='':
                continue
        if (i not in stop_words) and (len(i)<=8):
            if len(i)==1 and ord(i)==10:
                continue
            seg.append(i)
    return seg

# %%
seg = segment(text)

# %%
len(seg)
# Out:
# 896

# %%
for i in seg:
    print(len(i), str(i))
# Out:
# 2 ##
# 2 每日
# 2 经济
# 2 新闻
# 4 void
# 2 每日
# 2 经济
# 2 新闻
# 1 微
# 2 信号
# 7 nbdnews
# 2 功能
# 2 介绍
# 2 新闻
# 3 影响力
# 4 ____
# 2 __
# 3 没想到
# 2 一场
# 3 口水仗
# 2 引来
# 6 国家税务总局
# 2 关注
# 1 月
# 1 日
# 3 崔永元
# 2 微博
# 1 手
# 1 撕
# 3 范冰冰
# 4 最新进展
# 4 今天上午
# 4 法制日报
# 2 报道
# 3 无锡市
# 3 滨湖区
# 3 地税局
# 2 介入
# 4 调查取证
# 2 相关
# 2 情况
# 2 有待
# 2 后续
# 4 税务机关
# 2 权威
# 2 发布
# 4 今天下午
# 2 15
# 2 54
# 6 国家税务总局
# 2 近日
# 2 网上
# 2 影视
# 4 从业人员
# 2 签订
# 2 阴阳
# 2 合同
# 2 涉税
# 6 国家税务总局
# 4 高度重视
# 2 责成
# 2 江苏
# 4 税务机关
# 2 依法
# 4 调查核实
# 2 发现
# 2 违反
# 4 税收法律
# 2 法规
# 4 依法处理
# 2 下午
# 2 17
# 2 00
# 3 江苏省
# 3 地税局
# 2 组织
# 2 主管
# 4 税务机关
# 2 依法
# 4 调查核实
# 2 发现
# 2 违反
# 4 税收法律
# 2 法规
# 4 依法处理
# 2 月底
# 3 崔永元
# 3 微博上
# 2 炮轰
# 2 手机
# 2 剧组
# 2 成员
# 2 一场
# 2 嘴仗
# 3 没想到
# 1 月
# 2 28
# 1 日
# 2 29
# 1 日
# 3 崔永元
# 2 晒出
# 2 一大
# 2 一小
# 2 两份
# 2 合同
# 2 合同
# 3 范冰冰
# 2 名字
# 2 此前
# 2 每日
# 2 经济
# 2 新闻
# 1 微
# 2 信号
# 7 nbdnews
# 3 崔永元
# 2 微博
# 1 手
# 1 撕
# 3 范冰冰
# 2 掀开
# 3 影视圈
# 2 秘密
# 2 mp
# 6 weixin
# 2 qq
# 2 __
# 3 biz
# 3 mid
# 3 idx
# 2 sn
# ...

# %%
chr(10)
# Out:
# '\n'

# %%
text
# Out:
# '##\n\n[ 每日经济新闻 ](javascript:void\\(0\\);)\n\n**每日经济新闻** ![]()\n\n微信号 nbdnews\n\n功能介绍 【新闻决定影响力】\n\n____\n\n__\n\n没想到，一场“口水仗”引来了国家税务总局的关注！  \n\n  \n\n今天（6月3日），崔永元微博“手撕”范冰冰有了最新进展：\n\n  \n\n今天上午，《法制日报》报道，无锡市滨湖区地税局目前已经介入调查取证，相关情况有待后续由税务机关权威发布。\n\n  \n\n今天下午15:54，国家税务总局表示，针对近日网上反映有关影视从业人员签订“阴阳合同”中的涉税问题，国家税务总局高度重视，已责成江苏等地税务机关依法开展调查核实。如发现违反税收法律法规的行为，将严格依法处理。\n\n  \n\n下午17:00左右，江苏省地税局表示，已组织主管税务机关等依法开展调查核实。如发现违反税收法律法规的行为，将严格依法处理。\n\n  \n\n5月底，崔永元开始在微博上炮轰《手机2》剧组成员。起初，大家都以为这只是一场嘴仗，没想到，5月28日、29日，崔永元晒出了一大一小两份合同，其中，“小合同”出现了范冰冰的名字。\n\n  \n\n此前，每日经济新闻（微信号：nbdnews）在《[崔永元微博“手撕”范冰冰，掀开影视圈的一个秘密](https://mp.weixin.qq.com/s?__biz=ODYzMzExMzQx&mid=2652738135&idx=1&sn=ec02c155931a3e615cc8c9d3d65b5297&chksm=00a3d0d537d459c366aa52b2cd3d4b18986c35ee5a18e72bed0dc39bf0bce4a32c6d91506ffa&scene=21#wechat_redirect)》一文中，对此事进行了报道。\n\n  \n\n对于崔永元曝光的“大小合同”，范冰冰工作室回应称，“大小合同”未经求证核实、“4天片酬6千万”是谣言。\n\n  \n\n但事情并未因此结束，6月2日中午，崔永元的另一篇微博博文将此事引向了税务问题。  \n\n  \n\n  \n\n6月2日的微博中，崔永元直接点出“好像有个法律管这事儿”，并截图《刑法》条文。\n\n  \n\n  \n\n《刑法》第二百零
# ...

# %%
import re

# %%
# 匹配以(其括号开头)回括号结尾的所有字符串并且去掉
tag_pre = re.split(r'\(\S+?\)',text)

# %%
len(tag_pre)
# Out:
# 10

# %%
tag_pre
# Out:
# ['##\n\n[ 每日经济新闻 ]',
#  ';)\n\n**每日经济新闻** ![]()\n\n微信号 nbdnews\n\n功能介绍 【新闻决定影响力】\n\n____\n\n__\n\n没想到，一场“口水仗”引来了国家税务总局的关注！  \n\n  \n\n今天（6月3日），崔永元微博“手撕”范冰冰有了最新进展：\n\n  \n\n今天上午，《法制日报》报道，无锡市滨湖区地税局目前已经介入调查取证，相关情况有待后续由税务机关权威发布。\n\n  \n\n今天下午15:54，国家税务总局表示，针对近日网上反映有关影视从业人员签订“阴阳合同”中的涉税问题，国家税务总局高度重视，已责成江苏等地税务机关依法开展调查核实。如发现违反税收法律法规的行为，将严格依法处理。\n\n  \n\n下午17:00左右，江苏省地税局表示，已组织主管税务机关等依法开展调查核实。如发现违反税收法律法规的行为，将严格依法处理。\n\n  \n\n5月底，崔永元开始在微博上炮轰《手机2》剧组成员。起初，大家都以为这只是一场嘴仗，没想到，5月28日、29日，崔永元晒出了一大一小两份合同，其中，“小合同”出现了范冰冰的名字。\n\n  \n\n此前，每日经济新闻（微信号：nbdnews）在《[崔永元微博“手撕”范冰冰，掀开影视圈的一个秘密]',
# ...

# %%
re.s
# Out:
# 2

# %%
import requests
from html2text import html2text
import re

import jieba
from wordcloud import WordCloud

url = "https://mp.weixin.qq.com/s?src=11&timestamp=1528088401&ver=917&signature=mu7MyiQ-AK-rWoaQCDq7t81l39YvM4PRti-NwPkQ0q-JLDn4C2ezzP9jezDJeLNM0l3n0pjItw*6oLy7-ypfgyjyvskbMdCXR98pdMA2wlA-3uN7lTS1Le3IBmoB28GJ&new=1"

def segment(text):
    '''
    对一段text进行分词
    input：
    text:待分词的原始文章

    return:
    seg:分词后的text list
    '''
    source_text = text
    stop_words=[]
    # 得到分词原始list
    seg_list = list(jieba.cut((source_text), cut_all=False))

    # 加载停用词，转化为一个list一个词为一个项目
    with open('stop_words.txt') as f:
        stop_words = f.read().splitlines()
        
    # 将单个文档分词成为一个list，文档集合和文档list的集合
    seg=[]
    for i in seg_list:
        if i=='':
                continue
        if (i not in stop_words) and (len(i)<=8):
            if len(i)==1 and ord(i)==10:
                continue
            seg.append(i)
    return seg

r = requests.get(url)

text = html2text(r.text)

text = re.split(r'\(\S+?\)',text)
text = ''.join(text)

text = segment(text)
text = " ".join(text)

wordcloud = WordCloud(font_path = "msyh.ttf").generate(text)

import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
